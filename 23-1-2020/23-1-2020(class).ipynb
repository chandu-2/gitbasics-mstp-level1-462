# %%
import pandas as pd

# %%
df=pd.read_csv("ex1.csv")

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import sys

# %%
df.to_csv(sys.stdodut)
# Out:
# ,a,b,c,d,message
# 0,1,2,3,4,hello
# 1,5,6,7,8,world
# 2,9,10,11,12,foo

# %%
df.to_csv(sys.stdout,sep='1')
# Out:
# 1a1b1c1d1message
# 01"1"1213141hello
# "1"151617181world
# 2191"10"1"11"1"12"1foo

# %%
dates=pd.date_range("1/1/2020",periods=5)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
df1=pd.DataFrame(np.random.rand(5,4))
df1
# Out:
#           0         1         2         3
# 0  0.935220  0.242612  0.109964  0.749365
# 1  0.499065  0.245088  0.021903  0.236804
# 2  0.423637  0.337964  0.760251  0.130990
# 3  0.716871  0.995770  0.251121  0.311547
# 4  0.086790  0.875742  0.432293  0.524879

# %%
sample=df1.index=dates

# %%
sample=df1

# %%
sample
# Out:
#                    0         1         2         3
# 2020-01-01  0.935220  0.242612  0.109964  0.749365
# 2020-01-02  0.499065  0.245088  0.021903  0.236804
# 2020-01-03  0.423637  0.337964  0.760251  0.130990
# 2020-01-04  0.716871  0.995770  0.251121  0.311547
# 2020-01-05  0.086790  0.875742  0.432293  0.524879

# %%
samplecheck=sample.to_csv("samplecheck.csv")

# %%
s=pd.read_csv("samplecheck.csv")
s
# Out:
#    Unnamed: 0         0         1         2         3
# 0  2020-01-01  0.935220  0.242612  0.109964  0.749365
# 1  2020-01-02  0.499065  0.245088  0.021903  0.236804
# 2  2020-01-03  0.423637  0.337964  0.760251  0.130990
# 3  2020-01-04  0.716871  0.995770  0.251121  0.311547
# 4  2020-01-05  0.086790  0.875742  0.432293  0.524879

# %%
s.to_html("htmlchecking-converted data")

# %%
#json
j='{"name":["pinky","push","pop"],"age":[23,5,7]}'
j
# Out:
# '{"name":["pinky","push","pop"],"age":[23,5,7]}'

# %%
import json
r=json.loads(j)
r
# Out:
# {'name': ['pinky', 'push', 'pop'], 'age': [23, 5, 7]}

# %%
bank=pd.read_html('fdic_failed_bank_list.html')
bank
# Out:
# [                                  Bank Name             City  ST   CERT  \
#  0                               Allied Bank         Mulberry  AR     91
#  1              The Woodbury Banking Company         Woodbury  GA  11297
#  2                    First CornerStone Bank  King of Prussia  PA  35312
#  3                        Trust Company Bank          Memphis  TN   9956
#  4                North Milwaukee State Bank        Milwaukee  WI  20364
#  5                    Hometown National Bank         Longview  WA  35156
#  6                       The Bank of Georgia   Peachtree City  GA  35259
#  7                              Premier Bank           Denver  CO  34112
#  8                            Edgebrook Bank          Chicago  IL  57772
#  9                    Doral Bank  En Espanol         San Juan  PR  32102
#  10        Capitol City Bank & Trust Company          Atlanta  GA  33938
#  11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
len(bank)
# Out:
# 1

# %%
x=bank
x1=x[0]
x1
# Out:
#                                   Bank Name             City  ST   CERT  \
# 0                               Allied Bank         Mulberry  AR     91
# 1              The Woodbury Banking Company         Woodbury  GA  11297
# 2                    First CornerStone Bank  King of Prussia  PA  35312
# 3                        Trust Company Bank          Memphis  TN   9956
# 4                North Milwaukee State Bank        Milwaukee  WI  20364
# 5                    Hometown National Bank         Longview  WA  35156
# 6                       The Bank of Georgia   Peachtree City  GA  35259
# 7                              Premier Bank           Denver  CO  34112
# 8                            Edgebrook Bank          Chicago  IL  57772
# 9                    Doral Bank  En Espanol         San Juan  PR  32102
# 10        Capitol City Bank & Trust Company          Atlanta  GA  33938
# 11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
type(x)
# Out:
# list

# %%
print(type(x))
print(type(x1))
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x1["Updated Date"]
# Out:
# 0       November 17, 2016
# 1       November 17, 2016
# 2       September 6, 2016
# 3       September 6, 2016
# 4           June 16, 2016
# 5          April 13, 2016
# 6        October 24, 2016
# 7         August 17, 2016
# 8           July 12, 2016
# 9            May 13, 2015
# 10         April 21, 2015
# 11         April 21, 2015
# 12       January 15, 2016
# 13        January 6, 2016
# 14      November 10, 2016
# 15        January 6, 2016
# 16         March 26, 2015
# 17          July 28, 2015
# 18          July 11, 2016
# 19         March 25, 2016
# 20          June 29, 2015
# 21          June 26, 2015
# 22          June 15, 2015
# 23      November 10, 2016
# 24       October 20, 2016
# 25          July 18, 2014
# 26          March 3, 2015
# 27         March 03, 2015
# 28         April 12, 2016
# 29         March 25, 2016
#               ...
# 517       August 28, 2012
# 518       August 28, 2012
# 519      October 26, 2012
# 520    September 12, 2016
# 521       August 28, 2012
# ...

# %%
time=pd.to_datetime(x1["Updated Date"])
time
# Out:
# 0     2016-11-17
# 1     2016-11-17
# 2     2016-09-06
# 3     2016-09-06
# 4     2016-06-16
# 5     2016-04-13
# 6     2016-10-24
# 7     2016-08-17
# 8     2016-07-12
# 9     2015-05-13
# 10    2015-04-21
# 11    2015-04-21
# 12    2016-01-15
# 13    2016-01-06
# 14    2016-11-10
# 15    2016-01-06
# 16    2015-03-26
# 17    2015-07-28
# 18    2016-07-11
# 19    2016-03-25
# 20    2015-06-29
# 21    2015-06-26
# 22    2015-06-15
# 23    2016-11-10
# 24    2016-10-20
# 25    2014-07-18
# 26    2015-03-03
# 27    2015-03-03
# 28    2016-04-12
# 29    2016-03-25
#          ...
# 517   2012-08-28
# 518   2012-08-28
# 519   2012-10-26
# 520   2016-09-12
# 521   2012-08-28
# 522   2010-10-27
# 523   2008-04-09
# 524   2008-04-09
# 525   2012-06-05
# 526   2008-04-09
# 527   2005-07-22
# 528   2012-06-05
# 529   2008-10-20
# 530   2004-10-20
# 531   2005-03-18
# 532   2006-09-11
# 533   2008-04-09
# 534   2012-02-14
# 535   2005-03-18
# 536   2008-04-09
# 537   2015-02-05
# ...

# %%
time.dt.year.value_counts()
# Out:
# 2012    227
# 2014    109
# 2016     91
# 2015     66
# 2013     36
# 2008      6
# 2005      5
# 2004      2
# 2003      2
# 2010      1
# 2006      1
# 2002      1
# Name: Updated Date, dtype: int64

# %%
frame=pd.DataFrame(np.random.rand(5,5))

# %%
frame
# Out:
#           0         1         2         3         4
# 0  0.711851  0.786313  0.993489  0.916190  0.960295
# 1  0.083226  0.431147  0.345097  0.330177  0.089882
# 2  0.134441  0.380787  0.065070  0.844918  0.270838
# 3  0.229202  0.473831  0.349466  0.513471  0.996982
# 4  0.447096  0.063565  0.343193  0.365453  0.904026

# %%
frame.iloc[2,2]=np.nan

# %%
frame
# Out:
#           0         1         2         3         4
# 0  0.711851  0.786313  0.993489  0.916190  0.960295
# 1  0.083226  0.431147  0.345097  0.330177  0.089882
# 2  0.134441  0.380787       NaN  0.844918  0.270838
# 3  0.229202  0.473831  0.349466  0.513471  0.996982
# 4  0.447096  0.063565  0.343193  0.365453  0.904026

# %%
frame.iloc[:2,0:3]=np.nan
frame
# Out:
#           0         1         2         3         4
# 0       NaN       NaN       NaN       NaN  0.960295
# 1       NaN       NaN       NaN       NaN  0.089882
# 2  0.134441  0.380787       NaN  0.844918  0.270838
# 3  0.229202  0.473831  0.349466  0.513471  0.996982
# 4  0.447096  0.063565  0.343193  0.365453  0.904026

# %%
frame.isna()
# Out:
#        0      1      2      3      4
# 0   True   True   True   True  False
# 1   True   True   True   True  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
frame.dropna()
# Out:
#           0         1         2         3         4
# 3  0.229202  0.473831  0.349466  0.513471  0.996982
# 4  0.447096  0.063565  0.343193  0.365453  0.904026

# %%
frame.fillna(2)
# Out:
#           0         1         2         3         4
# 0  2.000000  2.000000  2.000000  2.000000  0.960295
# 1  2.000000  2.000000  2.000000  2.000000  0.089882
# 2  0.134441  0.380787  2.000000  0.844918  0.270838
# 3  0.229202  0.473831  0.349466  0.513471  0.996982
# 4  0.447096  0.063565  0.343193  0.365453  0.904026

# %%
frame.fillna({0:33,1:58,3:312})
# Out:
#            0          1         2           3         4
# 0  33.000000  58.000000       NaN  312.000000  0.960295
# 1  33.000000  58.000000       NaN  312.000000  0.089882
# 2   0.134441   0.380787       NaN    0.844918  0.270838
# 3   0.229202   0.473831  0.349466    0.513471  0.996982
# 4   0.447096   0.063565  0.343193    0.365453  0.904026

# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
# ...

# %%
#plot
#scatter plot
#bar plot
#histogram plot
#pie

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
x=[1,2,3,4]
y=[5,4,3,8]
plt.plot(x,y)

# %%
plt.plot(x,y,linewidth=1.5,markersize=10,color="green")

# %%
plt.plot(x,y,linewidth=1.5,markersize=10,color='green')
plt.xlabel("x")
plt.ylabel("y")
plt.title("graphing")
# Out:
# Text(0.5, 1.0, 'graphing')

# %%
x1=[2,5,7,8]
y1=[8,7,8,5]
plt.bar(x1,y1)
plt.bar(x,y,color="red")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar([1,3,4],[8,9,7],color="m")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\public\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# # historical graph

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=None, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, normed=None, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*,...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported at present.
#
#     Parameters
#     ----------
# ...

# %%
bins=[2,6,8,9,10]
plt.hist(x,bins,histtype="step",orientation="horizontal",color="pink")
# Out:
# (array([3., 0., 0., 0.]),
#  array([ 2,  6,  8,  9, 10]),
#  <a list of 1 Patch objects>)

# %%
plt.hist(x,bins,histtype="bar",orientation="horizontal",color="pink")
# Out:
# (array([3., 0., 0., 0.]),
#  array([ 2,  6,  8,  9, 10]),
#  <a list of 4 Patch objects>)

# %%
plt.style.use
# Out:
# <function matplotlib.style.core.use(style)>

# %%
plt.plot(x,y,)

# %%
plt.style.use("ggplot")

# %%
plt.plot(x,y,color="m")

# %%
plt.plot(x,y,color="r")
plt.plot(x1,y1,color="k")

# %%
p=[2,3,4,5]
q=[3,6,7,8]
s=[5,7,3,4]
plt.stackplot(p,q,s,colors=("m","k","b"))

# %%
plt.scatter(x,y,label="plott")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.plot(x,y,color="r",label="frist plot")
plt.plot(x1,y1,color="k",label="second plot")
plt.legend(loc="lowers left")
# Out:
# C:\Users\public\anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Unrecognized location 'lowers left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, data=None)
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.  If ``sum(x) < 1``, then the values of *x* give
#     the fractional area directly and the array will not be normalized. The
#     resulting pie will have an empty wedge of size ``1 - sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : array-like
#         The wedge sizes.
#
#     explode : array-like, optional, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
#         of the radius with which to offset each wedge.
#
# ...

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0xd1ffd17908>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '5'),
#   Text(0.33991867422268784, 1.0461621742897658, '4'),
#   Text(-1.0461621902025062, 0.3399186252483017, '3'),
#   Text(0.3399188211458418, -1.0461621265515308, '8')])

# %%
plt.pie(x,labels=y,startangle=3)
# Out:
# ([<matplotlib.patches.Wedge at 0xd1ffc007f0>,
# ...
#  [Text(1.0269384673015163, 0.3942047493072762, '5'),
#   Text(0.2847009297167426, 1.0625184142491002, '4'),
#   Text(-1.0625184275769115, 0.28470087997666543, '3'),
#   Text(0.3942048694934215, -1.026938421166369, '8')])

# %%
plt.pie(x,labels=y,startangle=30,autopct="%1.if%%")
# Out:
# ([<matplotlib.patches.Wedge at 0xd1ff8df278>,
# ...
#  [Text(0.736043663167941, 0.8174593114708026, '5'),
#   Text(-0.2287028800473084, 1.0759623565246448, '4'),
#   Text(-1.0759623458182892, -0.22870293041674067, '3'),
#   Text(0.8174593976125231, -0.7360435674978562, '8')],
#  [Text(0.40147836172796775, 0.4458868971658923, '10f%'),
#   Text(-0.12474702548035002, 0.5868885581043516, '20f%'),
#   Text(-0.5868885522645213, -0.12474705295458581, '30f%'),
#   Text(0.44588694415228525, -0.40147830954428515, '40f%')])

# %%
f=plt.figure()

# %%
ax1=f.add_subplot(2,2,1)

# %%
ax1

# %%
ax1.hist(np.random.rand(5),bins=[2,3,4,5,6])
# Out:
# (array([0., 0., 0., 0.]), array([2, 3, 4, 5, 6]), <a list of 4 Patch objects>)

# %%
# creat dataframe with student marks(5,6)
## total,average,min,max
## null values
# plot
## scatter plot
# stackplot

# %%
st_markes=pd.DataFrame(np.random.randn(5,6),index=[61,62,63,64,65],columns=['eng',"teg","hin","math","soc","bio"])

# %%
st_markes
# Out:
#          eng       teg       hin      math       soc       bio
# 61  0.612243  0.513171 -1.216869  0.252512 -1.321885 -0.810307
# 62 -0.821347  0.928772  0.376094 -0.097941 -0.844449  0.175666
# 63 -0.018100  0.670263  0.386799 -0.282718 -0.245288  0.874743
# 64 -0.392666 -0.300610  0.262569 -0.147068  0.974776 -0.712162
# 65  0.494366 -0.539733  0.413885 -2.213220 -0.172705  0.427801
